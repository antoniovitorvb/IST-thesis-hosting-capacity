# %%
import os, math, sys
import pandas as pd
import pandapower as pp
import numpy as np

from pandapower.file_io import from_json, to_json
import pandapower.networks as nw
from pandapower.timeseries import DFData

main_dir = os.path.abspath(os.path.join(os.path.abspath(""), ".."))
data_dir = os.path.join(main_dir, 'Modified_116_LV_CSV')

if main_dir not in sys.path:
    sys.path.insert(0, main_dir)
# Out:
# load C:\Users\vitor\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\ortools\.libs\zlib1.dll...
# load C:\Users\vitor\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\ortools\.libs\abseil_dll.dll...
# load C:\Users\vitor\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\ortools\.libs\utf8_validity.dll...
# load C:\Users\vitor\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\ortools\.libs\re2.dll...
# load C:\Users\vitor\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\ortools\.libs\libprotobuf.dll...
# load C:\Users\vitor\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\ortools\.libs\highs.dll...
# load C:\Users\vitor\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\ortools\.libs\ortools.dll...

# %% [markdown]
# ### test on nw.ieee_european_lv_asymmetric('off_peak_1440')

# %%
from pp_simu import hc_deterministic, addEV_det, addPV_det
import pandapower.networks as nw

net_off_peak_1 = nw.ieee_european_lv_asymmetric('off_peak_1')
net_on_peak_566 = nw.ieee_european_lv_asymmetric('on_peak_566')
net_off_peak_1440 = nw.ieee_european_lv_asymmetric('off_peak_1440')
# Out:
# Created External Grid!
# Created Transformer!
# Created Shunt!
# Created 117 Buses!
# Created 115 Lines!
#
# Debugging successful!
# This pandapower network includes the following parameter tables:
#    - bus (117 elements)
#    - shunt (1 element)
#    - ext_grid (1 element)
#    - line (115 elements)
#    - trafo (1 element)
#  and the following results tables:
#    - res_bus_3ph (117 elements)
#    - res_line_3ph (115 elements)
#    - res_trafo_3ph (1 element)
#    - res_ext_grid_3ph (1 element)
#    - res_shunt_3ph (1 element)

# %%
pv_hc_results = hc_deterministic(net_on_peak_566, add_kw=1.0, max_kw=20.0, pv=True, ev=False)

output_dir = os.path.join(main_dir, 'hc_resuls')
os.mkdir(os.path.join(main_dir, 'hc_resuls')) if not os.path.isdir(output_dir) else None

pv_hc_results.to_csv(os.path.join(output_dir, 'pv_hc_results_on_peak_566.csv'))
# Out:
# Overvoltage violation at bus 2, phase A with 0.0 kW
# Overvoltage violation at bus 2, phase A with 1.0 kW
# Overvoltage violation at bus 2, phase A with 2.0 kW
# Overvoltage violation at bus 2, phase A with 3.0 kW
# Overvoltage violation at bus 2, phase A with 4.0 kW
# Overvoltage violation at bus 2, phase A with 5.0 kW
# Overvoltage violation at bus 2, phase A with 6.0 kW
# Overvoltage violation at bus 2, phase A with 7.0 kW
# Overvoltage violation at bus 2, phase A with 8.0 kW
# Overvoltage violation at bus 2, phase A with 9.0 kW
# Overvoltage violation at bus 2, phase A with 10.0 kW
# Overvoltage violation at bus 2, phase A with 11.0 kW
# Overvoltage violation at bus 2, phase A with 12.0 kW
# Overvoltage violation at bus 2, phase A with 13.0 kW
# Overvoltage violation at bus 2, phase A with 14.0 kW
# Overvoltage violation at bus 2, phase A with 15.0 kW
# Overvoltage violation at bus 2, phase A with 16.0 kW
# Overvoltage violation at bus 2, phase A with 17.0 kW
# Overvoltage violation at bus 2, phase A with 18.0 kW
# Overvoltage violation at bus 2, phase A with 19.0 kW
# Overvoltage violation at bus 2, phase A with 20.0 kW
# Overvoltage violation at bus 2, phase B with 0.0 kW
# Overvoltage violation at bus 2, phase B with 1.0 kW
# Overvoltage violation at bus 2, phase B with 2.0 kW
# Overvoltage violation at bus 2, phase B with 3.0 kW
# Overvoltage violation at bus 2, phase B with 4.0 kW
# Overvoltage violation at bus 2, phase B with 5.0 kW
# Overvoltage violation at bus 2, phase B with 6.0 kW
# Overvoltage violation at bus 2, phase B with 7.0 kW
# Overvoltage violation at bus 2, phase B with 8.0 kW
# Overvoltage violation at bus 2, phase B with 9.0 kW
# Overvoltage violation at bus 2, phase B with 10.0 kW
# Overvoltage violation at bus 2, phase B with 11.0 kW
# Overvoltage violation at bus 2, phase B with 12.0 kW
# Overvoltage violation at bus 2, phase B with 13.0 kW
# Overvoltage violation at bus 2, phase B with 14.0 kW
# Overvoltage violation at bus 2, phase B with 15.0 kW
# Overvoltage violation at bus 2, phase B with 16.0 kW
# Overvoltage violation at bus 2, phase B with 17.0 kW
# Overvoltage violation at bus 2, phase B with 18.0 kW
# Overvoltage violation at bus 2, phase B with 19.0 kW
# Overvoltage violation at bus 2, phase B with 20.0 kW
# Overvoltage violation at bus 2, phase C with 0.0 kW
# Overvoltage violation at bus 2, phase C with 1.0 kW
# Overvoltage violation at bus 2, phase C with 2.0 kW
# Overvoltage violation at bus 2, phase C with 3.0 kW
# Overvoltage violation at bus 2, phase C with 4.0 kW
# Overvoltage violation at bus 2, phase C with 5.0 kW
# Overvoltage violation at bus 2, phase C with 6.0 kW
# Overvoltage violation at bus 2, phase C with 7.0 kW
# Overvoltage violation at bus 2, phase C with 8.0 kW
# Overvoltage violation at bus 2, phase C with 9.0 kW
# Overvoltage violation at bus 2, phase C with 10.0 kW
# Overvoltage violation at bus 2, phase C with 11.0 kW
# Overvoltage violation at bus 2, phase C with 12.0 kW
# Overvoltage violation at bus 2, phase C with 13.0 kW
# Overvoltage violation at bus 2, phase C with 14.0 kW
# Overvoltage violation at bus 2, phase C with 15.0 kW
# Overvoltage violation at bus 2, phase C with 16.0 kW
# Overvoltage violation at bus 2, phase C with 17.0 kW
# Overvoltage violation at bus 2, phase C with 18.0 kW
# Overvoltage violation at bus 2, phase C with 19.0 kW
# Overvoltage violation at bus 2, phase C with 20.0 kW
# Overvoltage violation at bus 3, phase A with 0.0 kW
# Overvoltage violation at bus 3, phase A with 1.0 kW
# Overvoltage violation at bus 3, phase A with 2.0 kW
# Overvoltage violation at bus 3, phase A with 3.0 kW
# Overvoltage violation at bus 3, phase A with 4.0 kW
# Overvoltage violation at bus 3, phase A with 5.0 kW
# Overvoltage violation at bus 3, phase A with 6.0 kW
# Overvoltage violation at bus 3, phase A with 7.0 kW
# Overvoltage violation at bus 3, phase A with 8.0 kW
# Overvoltage violation at bus 3, phase A with 9.0 kW
# Overvoltage violation at bus 3, phase A with 10.0 kW
# Overvoltage violation at bus 3, phase A with 11.0 kW
# Overvoltage violation at bus 3, phase A with 12.0 kW
# Overvoltage violation at bus 3, phase A with 13.0 kW
# Overvoltage violation at bus 3, phase A with 14.0 kW
# Overvoltage violation at bus 3, phase A with 15.0 kW
# Overvoltage violation at bus 3, phase A with 16.0 kW
# Overvoltage violation at bus 3, phase A with 17.0 kW
# Overvoltage violation at bus 3, phase A with 18.0 kW
# Overvoltage violation at bus 3, phase A with 19.0 kW
# Overvoltage violation at bus 3, phase A with 20.0 kW
# Overvoltage violation at bus 3, phase B with 0.0 kW
# Overvoltage violation at bus 3, phase B with 1.0 kW
# Overvoltage violation at bus 3, phase B with 2.0 kW
# Overvoltage violation at bus 3, phase B with 3.0 kW
# Overvoltage violation at bus 3, phase B with 4.0 kW
# Overvoltage violation at bus 3, phase B with 5.0 kW
# Overvoltage violation at bus 3, phase B with 6.0 kW
# Overvoltage violation at bus 3, phase B with 7.0 kW
# Overvoltage violation at bus 3, phase B with 8.0 kW
# Overvoltage violation at bus 3, phase B with 9.0 kW
# Overvoltage violation at bus 3, phase B with 10.0 kW
# Overvoltage violation at bus 3, phase B with 11.0 kW
# Overvoltage violation at bus 3, phase B with 12.0 kW
# Overvoltage violation at bus 3, phase B with 13.0 kW
# Overvoltage violation at bus 3, phase B with 14.0 kW
# Overvoltage violation at bus 3, phase B with 15.0 kW
# Overvoltage violation at bus 3, phase B with 16.0 kW
# Overvoltage violation at bus 3, phase B with 17.0 kW
# Overvoltage violation at bus 3, phase B with 18.0 kW
# Overvoltage violation at bus 3, phase B with 19.0 kW
# Overvoltage violation at bus 3, phase B with 20.0 kW
# Overvoltage violation at bus 3, phase C with 0.0 kW
# Overvoltage violation at bus 3, phase C with 1.0 kW
# Overvoltage violation at bus 3, phase C with 2.0 kW
# Overvoltage violation at bus 3, phase C with 3.0 kW
# Overvoltage violation at bus 3, phase C with 4.0 kW
# Overvoltage violation at bus 3, phase C with 5.0 kW
# Overvoltage violation at bus 3, phase C with 6.0 kW
# Overvoltage violation at bus 3, phase C with 7.0 kW
# Overvoltage violation at bus 3, phase C with 8.0 kW
# Overvoltage violation at bus 3, phase C with 9.0 kW
# Overvoltage violation at bus 3, phase C with 10.0 kW
# Overvoltage violation at bus 3, phase C with 11.0 kW
# Overvoltage violation at bus 3, phase C with 12.0 kW
# Overvoltage violation at bus 3, phase C with 13.0 kW
# Overvoltage violation at bus 3, phase C with 14.0 kW
# Overvoltage violation at bus 3, phase C with 15.0 kW
# Overvoltage violation at bus 3, phase C with 16.0 kW
# Overvoltage violation at bus 3, phase C with 17.0 kW
# Overvoltage violation at bus 3, phase C with 18.0 kW
# Overvoltage violation at bus 3, phase C with 19.0 kW
# Overvoltage violation at bus 3, phase C with 20.0 kW
# Overvoltage violation at bus 4, phase A with 0.0 kW
# Overvoltage violation at bus 4, phase A with 1.0 kW
# Overvoltage violation at bus 4, phase A with 2.0 kW
# Overvoltage violation at bus 4, phase A with 3.0 kW
# Overvoltage violation at bus 4, phase A with 4.0 kW
# Overvoltage violation at bus 4, phase A with 5.0 kW
# Overvoltage violation at bus 4, phase A with 6.0 kW
# Overvoltage violation at bus 4, phase A with 7.0 kW
# Overvoltage violation at bus 4, phase A with 8.0 kW
# Overvoltage violation at bus 4, phase A with 9.0 kW
# Overvoltage violation at bus 4, phase A with 10.0 kW
# Overvoltage violation at bus 4, phase A with 11.0 kW
# Overvoltage violation at bus 4, phase A with 12.0 kW
# Overvoltage violation at bus 4, phase A with 13.0 kW
# Overvoltage violation at bus 4, phase A with 14.0 kW
# Overvoltage violation at bus 4, phase A with 15.0 kW
# Overvoltage violation at bus 4, phase A with 16.0 kW
# Overvoltage violation at bus 4, phase A with 17.0 kW
# Overvoltage violation at bus 4, phase A with 18.0 kW
# Overvoltage violation at bus 4, phase A with 19.0 kW
# Overvoltage violation at bus 4, phase A with 20.0 kW
# Overvoltage violation at bus 4, phase B with 0.0 kW
# Overvoltage violation at bus 4, phase B with 1.0 kW
# Overvoltage violation at bus 4, phase B with 2.0 kW
# Overvoltage violation at bus 4, phase B with 3.0 kW
# Overvoltage violation at bus 4, phase B with 4.0 kW
# Overvoltage violation at bus 4, phase B with 5.0 kW
# Overvoltage violation at bus 4, phase B with 6.0 kW
# Overvoltage violation at bus 4, phase B with 7.0 kW
# Overvoltage violation at bus 4, phase B with 8.0 kW
# Overvoltage violation at bus 4, phase B with 9.0 kW
# Overvoltage violation at bus 4, phase B with 10.0 kW
# Overvoltage violation at bus 4, phase B with 11.0 kW
# Overvoltage violation at bus 4, phase B with 12.0 kW
# Overvoltage violation at bus 4, phase B with 13.0 kW
# Overvoltage violation at bus 4, phase B with 14.0 kW
# Overvoltage violation at bus 4, phase B with 15.0 kW
# Overvoltage violation at bus 4, phase B with 16.0 kW
# Overvoltage violation at bus 4, phase B with 17.0 kW
# Overvoltage violation at bus 4, phase B with 18.0 kW
# Overvoltage violation at bus 4, phase B with 19.0 kW
# Overvoltage violation at bus 4, phase B with 20.0 kW
# Overvoltage violation at bus 4, phase C with 0.0 kW
# Overvoltage violation at bus 4, phase C with 1.0 kW
# Overvoltage violation at bus 4, phase C with 2.0 kW
# Overvoltage violation at bus 4, phase C with 3.0 kW
# Overvoltage violation at bus 4, phase C with 4.0 kW
# Overvoltage violation at bus 4, phase C with 5.0 kW
# Overvoltage violation at bus 4, phase C with 6.0 kW
# Overvoltage violation at bus 4, phase C with 7.0 kW
# Overvoltage violation at bus 4, phase C with 8.0 kW
# Overvoltage violation at bus 4, phase C with 9.0 kW
# Overvoltage violation at bus 4, phase C with 10.0 kW
# Overvoltage violation at bus 4, phase C with 11.0 kW
# Overvoltage violation at bus 4, phase C with 12.0 kW
# Overvoltage violation at bus 4, phase C with 13.0 kW
# Overvoltage violation at bus 4, phase C with 14.0 kW
# Overvoltage violation at bus 4, phase C with 15.0 kW
# Overvoltage violation at bus 4, phase C with 16.0 kW
# Overvoltage violation at bus 4, phase C with 17.0 kW
# Overvoltage violation at bus 4, phase C with 18.0 kW
# Overvoltage violation at bus 4, phase C with 19.0 kW
# Overvoltage violation at bus 4, phase C with 20.0 kW
# Overvoltage violation at bus 5, phase A with 0.0 kW
# Overvoltage violation at bus 5, phase A with 1.0 kW
# Overvoltage violation at bus 5, phase A with 2.0 kW
# Overvoltage violation at bus 5, phase A with 3.0 kW
# Overvoltage violation at bus 5, phase A with 4.0 kW
# Overvoltage violation at bus 5, phase A with 5.0 kW
# Overvoltage violation at bus 5, phase A with 6.0 kW
# Overvoltage violation at bus 5, phase A with 7.0 kW
# Overvoltage violation at bus 5, phase A with 8.0 kW
# Overvoltage violation at bus 5, phase A with 9.0 kW
# Overvoltage violation at bus 5, phase A with 10.0 kW
# Overvoltage violation at bus 5, phase A with 11.0 kW
# Overvoltage violation at bus 5, phase A with 12.0 kW
# Overvoltage violation at bus 5, phase A with 13.0 kW
# Overvoltage violation at bus 5, phase A with 14.0 kW
# Overvoltage violation at bus 5, phase A with 15.0 kW
# Overvoltage violation at bus 5, phase A with 16.0 kW
# Overvoltage violation at bus 5, phase A with 17.0 kW
# Overvoltage violation at bus 5, phase A with 18.0 kW
# Overvoltage violation at bus 5, phase A with 19.0 kW
# Overvoltage violation at bus 5, phase A with 20.0 kW
# Overvoltage violation at bus 5, phase B with 0.0 kW
# Overvoltage violation at bus 5, phase B with 1.0 kW
# Overvoltage violation at bus 5, phase B with 2.0 kW
# Overvoltage violation at bus 5, phase B with 3.0 kW
# Overvoltage violation at bus 5, phase B with 4.0 kW
# Overvoltage violation at bus 5, phase B with 5.0 kW
# Overvoltage violation at bus 5, phase B with 6.0 kW
# Overvoltage violation at bus 5, phase B with 7.0 kW
# Overvoltage violation at bus 5, phase B with 8.0 kW
# Overvoltage violation at bus 5, phase B with 9.0 kW
# Overvoltage violation at bus 5, phase B with 10.0 kW
# Overvoltage violation at bus 5, phase B with 11.0 kW
# Overvoltage violation at bus 5, phase B with 12.0 kW
# Overvoltage violation at bus 5, phase B with 13.0 kW
# Overvoltage violation at bus 5, phase B with 14.0 kW
# Overvoltage violation at bus 5, phase B with 15.0 kW
# Overvoltage violation at bus 5, phase B with 16.0 kW
# Overvoltage violation at bus 5, phase B with 17.0 kW
# Overvoltage violation at bus 5, phase B with 18.0 kW
# Overvoltage violation at bus 5, phase B with 19.0 kW
# Overvoltage violation at bus 5, phase B with 20.0 kW
# Overvoltage violation at bus 5, phase C with 0.0 kW
# Overvoltage violation at bus 5, phase C with 1.0 kW
# Overvoltage violation at bus 5, phase C with 2.0 kW
# Overvoltage violation at bus 5, phase C with 3.0 kW
# Overvoltage violation at bus 5, phase C with 4.0 kW
# Overvoltage violation at bus 5, phase C with 5.0 kW
# Overvoltage violation at bus 5, phase C with 6.0 kW
# Overvoltage violation at bus 5, phase C with 7.0 kW
# Overvoltage violation at bus 5, phase C with 8.0 kW
# Overvoltage violation at bus 5, phase C with 9.0 kW
# Overvoltage violation at bus 5, phase C with 10.0 kW
# Overvoltage violation at bus 5, phase C with 11.0 kW
# Overvoltage violation at bus 5, phase C with 12.0 kW
# Overvoltage violation at bus 5, phase C with 13.0 kW
# Overvoltage violation at bus 5, phase C with 14.0 kW
# Overvoltage violation at bus 5, phase C with 15.0 kW
# Overvoltage violation at bus 5, phase C with 16.0 kW
# Overvoltage violation at bus 5, phase C with 17.0 kW
# Overvoltage violation at bus 5, phase C with 18.0 kW
# Overvoltage violation at bus 5, phase C with 19.0 kW
# Overvoltage violation at bus 5, phase C with 20.0 kW
# Overvoltage violation at bus 6, phase A with 0.0 kW
# Overvoltage violation at bus 6, phase A with 1.0 kW
# Overvoltage violation at bus 6, phase A with 2.0 kW
# Overvoltage violation at bus 6, phase A with 3.0 kW
# Overvoltage violation at bus 6, phase A with 4.0 kW
# Overvoltage violation at bus 6, phase A with 5.0 kW
# Overvoltage violation at bus 6, phase A with 6.0 kW
# Overvoltage violation at bus 6, phase A with 7.0 kW
# Overvoltage violation at bus 6, phase A with 8.0 kW
# Overvoltage violation at bus 6, phase A with 9.0 kW
# Overvoltage violation at bus 6, phase A with 10.0 kW
# Overvoltage violation at bus 6, phase A with 11.0 kW
# Overvoltage violation at bus 6, phase A with 12.0 kW
# Overvoltage violation at bus 6, phase A with 13.0 kW
# Overvoltage violation at bus 6, phase A with 14.0 kW
# Overvoltage violation at bus 6, phase A with 15.0 kW
# Overvoltage violation at bus 6, phase A with 16.0 kW
# Overvoltage violation at bus 6, phase A with 17.0 kW
# Overvoltage violation at bus 6, phase A with 18.0 kW
# Overvoltage violation at bus 6, phase A with 19.0 kW
# Overvoltage violation at bus 6, phase A with 20.0 kW
# Overvoltage violation at bus 6, phase B with 0.0 kW
# Overvoltage violation at bus 6, phase B with 1.0 kW
# Overvoltage violation at bus 6, phase B with 2.0 kW
# Overvoltage violation at bus 6, phase B with 3.0 kW
# Overvoltage violation at bus 6, phase B with 4.0 kW
# Overvoltage violation at bus 6, phase B with 5.0 kW
# Overvoltage violation at bus 6, phase B with 6.0 kW
# Overvoltage violation at bus 6, phase B with 7.0 kW
# Overvoltage violation at bus 6, phase B with 8.0 kW
# Overvoltage violation at bus 6, phase B with 9.0 kW
# Overvoltage violation at bus 6, phase B with 10.0 kW
# Overvoltage violation at bus 6, phase B with 11.0 kW
# Overvoltage violation at bus 6, phase B with 12.0 kW
# Overvoltage violation at bus 6, phase B with 13.0 kW
# Overvoltage violation at bus 6, phase B with 14.0 kW
# Overvoltage violation at bus 6, phase B with 15.0 kW
# Overvoltage violation at bus 6, phase B with 16.0 kW
# Overvoltage violation at bus 6, phase B with 17.0 kW
# Overvoltage violation at bus 6, phase B with 18.0 kW
# Overvoltage violation at bus 6, phase B with 19.0 kW
# Overvoltage violation at bus 6, phase B with 20.0 kW
# Overvoltage violation at bus 6, phase C with 0.0 kW
# Overvoltage violation at bus 6, phase C with 1.0 kW
# Overvoltage violation at bus 6, phase C with 2.0 kW
# Overvoltage violation at bus 6, phase C with 3.0 kW
# Overvoltage violation at bus 6, phase C with 4.0 kW
# Overvoltage violation at bus 6, phase C with 5.0 kW
# Overvoltage violation at bus 6, phase C with 6.0 kW
# Overvoltage violation at bus 6, phase C with 7.0 kW
# Overvoltage violation at bus 6, phase C with 8.0 kW
# Overvoltage violation at bus 6, phase C with 9.0 kW
# Overvoltage violation at bus 6, phase C with 10.0 kW
# Overvoltage violation at bus 6, phase C with 11.0 kW
# Overvoltage violation at bus 6, phase C with 12.0 kW
# Overvoltage violation at bus 6, phase C with 13.0 kW
# Overvoltage violation at bus 6, phase C with 14.0 kW
# Overvoltage violation at bus 6, phase C with 15.0 kW
# Overvoltage violation at bus 6, phase C with 16.0 kW
# Overvoltage violation at bus 6, phase C with 17.0 kW
# Overvoltage violation at bus 6, phase C with 18.0 kW
# Overvoltage violation at bus 6, phase C with 19.0 kW
# Overvoltage violation at bus 6, phase C with 20.0 kW
# Overvoltage violation at bus 7, phase A with 0.0 kW
# Overvoltage violation at bus 7, phase A with 1.0 kW
# Overvoltage violation at bus 7, phase A with 2.0 kW
# Overvoltage violation at bus 7, phase A with 3.0 kW
# Overvoltage violation at bus 7, phase A with 4.0 kW
# Overvoltage violation at bus 7, phase A with 5.0 kW
# Overvoltage violation at bus 7, phase A with 6.0 kW
# Overvoltage violation at bus 7, phase A with 7.0 kW
# Overvoltage violation at bus 7, phase A with 8.0 kW
# Overvoltage violation at bus 7, phase A with 9.0 kW
# Overvoltage violation at bus 7, phase A with 10.0 kW
# Overvoltage violation at bus 7, phase A with 11.0 kW
# Overvoltage violation at bus 7, phase A with 12.0 kW
# Overvoltage violation at bus 7, phase A with 13.0 kW
# Overvoltage violation at bus 7, phase A with 14.0 kW
# Overvoltage violation at bus 7, phase A with 15.0 kW
# Overvoltage violation at bus 7, phase A with 16.0 kW
# Overvoltage violation at bus 7, phase A with 17.0 kW
# Overvoltage violation at bus 7, phase A with 18.0 kW
# Overvoltage violation at bus 7, phase A with 19.0 kW
# Overvoltage violation at bus 7, phase A with 20.0 kW
# Overvoltage violation at bus 7, phase B with 0.0 kW
# Overvoltage violation at bus 7, phase B with 1.0 kW
# Overvoltage violation at bus 7, phase B with 2.0 kW
# Overvoltage violation at bus 7, phase B with 3.0 kW
# Overvoltage violation at bus 7, phase B with 4.0 kW
# Overvoltage violation at bus 7, phase B with 5.0 kW
# Overvoltage violation at bus 7, phase B with 6.0 kW
# Overvoltage violation at bus 7, phase B with 7.0 kW
# Overvoltage violation at bus 7, phase B with 8.0 kW
# Overvoltage violation at bus 7, phase B with 9.0 kW
# Overvoltage violation at bus 7, phase B with 10.0 kW
# Overvoltage violation at bus 7, phase B with 11.0 kW
# Overvoltage violation at bus 7, phase B with 12.0 kW
# Overvoltage violation at bus 7, phase B with 13.0 kW
# Overvoltage violation at bus 7, phase B with 14.0 kW
# Overvoltage violation at bus 7, phase B with 15.0 kW
# Overvoltage violation at bus 7, phase B with 16.0 kW
# Overvoltage violation at bus 7, phase B with 17.0 kW
# Overvoltage violation at bus 7, phase B with 18.0 kW
# Overvoltage violation at bus 7, phase B with 19.0 kW
# Overvoltage violation at bus 7, phase B with 20.0 kW
# Overvoltage violation at bus 7, phase C with 0.0 kW
# Overvoltage violation at bus 7, phase C with 1.0 kW
# Overvoltage violation at bus 7, phase C with 2.0 kW
# Overvoltage violation at bus 7, phase C with 3.0 kW
# Overvoltage violation at bus 7, phase C with 4.0 kW
# Overvoltage violation at bus 7, phase C with 5.0 kW
# Overvoltage violation at bus 7, phase C with 6.0 kW
# Overvoltage violation at bus 7, phase C with 7.0 kW
# Overvoltage violation at bus 7, phase C with 8.0 kW
# Overvoltage violation at bus 7, phase C with 9.0 kW
# Overvoltage violation at bus 7, phase C with 10.0 kW
# Overvoltage violation at bus 7, phase C with 11.0 kW
# Overvoltage violation at bus 7, phase C with 12.0 kW
# Overvoltage violation at bus 7, phase C with 13.0 kW
# Overvoltage violation at bus 7, phase C with 14.0 kW
# Overvoltage violation at bus 7, phase C with 15.0 kW
# Overvoltage violation at bus 7, phase C with 16.0 kW
# Overvoltage violation at bus 7, phase C with 17.0 kW
# Overvoltage violation at bus 7, phase C with 18.0 kW
# Overvoltage violation at bus 7, phase C with 19.0 kW
# Overvoltage violation at bus 7, phase C with 20.0 kW
# Overvoltage violation at bus 8, phase A with 0.0 kW
# Overvoltage violation at bus 8, phase A with 1.0 kW
# Overvoltage violation at bus 8, phase A with 2.0 kW
# Overvoltage violation at bus 8, phase A with 3.0 kW
# Overvoltage violation at bus 8, phase A with 4.0 kW
# Overvoltage violation at bus 8, phase A with 5.0 kW
# Overvoltage violation at bus 8, phase A with 6.0 kW
# Overvoltage violation at bus 8, phase A with 7.0 kW
# Overvoltage violation at bus 8, phase A with 8.0 kW
# Overvoltage violation at bus 8, phase A with 9.0 kW
# Overvoltage violation at bus 8, phase A with 10.0 kW
# Overvoltage violation at bus 8, phase A with 11.0 kW
# Overvoltage violation at bus 8, phase A with 12.0 kW
# Overvoltage violation at bus 8, phase A with 13.0 kW
# Overvoltage violation at bus 8, phase A with 14.0 kW
# Overvoltage violation at bus 8, phase A with 15.0 kW
# Overvoltage violation at bus 8, phase A with 16.0 kW
# Overvoltage violation at bus 8, phase A with 17.0 kW
# Overvoltage violation at bus 8, phase A with 18.0 kW
# Overvoltage violation at bus 8, phase A with 19.0 kW
# Overvoltage violation at bus 8, phase A with 20.0 kW
# Overvoltage violation at bus 8, phase B with 0.0 kW
# Overvoltage violation at bus 8, phase B with 1.0 kW
# Overvoltage violation at bus 8, phase B with 2.0 kW
# Overvoltage violation at bus 8, phase B with 3.0 kW
# Overvoltage violation at bus 8, phase B with 4.0 kW
# Overvoltage violation at bus 8, phase B with 5.0 kW
# Overvoltage violation at bus 8, phase B with 6.0 kW
# Overvoltage violation at bus 8, phase B with 7.0 kW
# Overvoltage violation at bus 8, phase B with 8.0 kW
# Overvoltage violation at bus 8, phase B with 9.0 kW
# Overvoltage violation at bus 8, phase B with 10.0 kW
# Overvoltage violation at bus 8, phase B with 11.0 kW
# Overvoltage violation at bus 8, phase B with 12.0 kW
# Overvoltage violation at bus 8, phase B with 13.0 kW
# Overvoltage violation at bus 8, phase B with 14.0 kW
# Overvoltage violation at bus 8, phase B with 15.0 kW
# Overvoltage violation at bus 8, phase B with 16.0 kW
# Overvoltage violation at bus 8, phase B with 17.0 kW
# Overvoltage violation at bus 8, phase B with 18.0 kW
# Overvoltage violation at bus 8, phase B with 19.0 kW
# Overvoltage violation at bus 8, phase B with 20.0 kW
# Overvoltage violation at bus 8, phase C with 0.0 kW
# Overvoltage violation at bus 8, phase C with 1.0 kW
# Overvoltage violation at bus 8, phase C with 2.0 kW
# Overvoltage violation at bus 8, phase C with 3.0 kW
# Overvoltage violation at bus 8, phase C with 4.0 kW
# Overvoltage violation at bus 8, phase C with 5.0 kW
# Overvoltage violation at bus 8, phase C with 6.0 kW
# Overvoltage violation at bus 8, phase C with 7.0 kW
# Overvoltage violation at bus 8, phase C with 8.0 kW
# Overvoltage violation at bus 8, phase C with 9.0 kW
# Overvoltage violation at bus 8, phase C with 10.0 kW
# Overvoltage violation at bus 8, phase C with 11.0 kW
# Overvoltage violation at bus 8, phase C with 12.0 kW
# Overvoltage violation at bus 8, phase C with 13.0 kW
# Overvoltage violation at bus 8, phase C with 14.0 kW
# Overvoltage violation at bus 8, phase C with 15.0 kW
# Overvoltage violation at bus 8, phase C with 16.0 kW
# Overvoltage violation at bus 8, phase C with 17.0 kW
# Overvoltage violation at bus 8, phase C with 18.0 kW
# Overvoltage violation at bus 8, phase C with 19.0 kW
# Overvoltage violation at bus 8, phase C with 20.0 kW
# Overvoltage violation at bus 9, phase A with 0.0 kW
# Overvoltage violation at bus 9, phase A with 1.0 kW
# Overvoltage violation at bus 9, phase A with 2.0 kW
# Overvoltage violation at bus 9, phase A with 3.0 kW
# Overvoltage violation at bus 9, phase A with 4.0 kW
# Overvoltage violation at bus 9, phase A with 5.0 kW
# Overvoltage violation at bus 9, phase A with 6.0 kW
# Overvoltage violation at bus 9, phase A with 7.0 kW
# Overvoltage violation at bus 9, phase A with 8.0 kW
# Overvoltage violation at bus 9, phase A with 9.0 kW
# Overvoltage violation at bus 9, phase A with 10.0 kW
# Overvoltage violation at bus 9, phase A with 11.0 kW
# Overvoltage violation at bus 9, phase A with 12.0 kW
# Overvoltage violation at bus 9, phase A with 13.0 kW
# Overvoltage violation at bus 9, phase A with 14.0 kW
# Overvoltage violation at bus 9, phase A with 15.0 kW
# Overvoltage violation at bus 9, phase A with 16.0 kW
# Overvoltage violation at bus 9, phase A with 17.0 kW
# Overvoltage violation at bus 9, phase A with 18.0 kW
# Overvoltage violation at bus 9, phase A with 19.0 kW
# Overvoltage violation at bus 9, phase A with 20.0 kW
# Overvoltage violation at bus 9, phase B with 0.0 kW
# Overvoltage violation at bus 9, phase B with 1.0 kW
# Overvoltage violation at bus 9, phase B with 2.0 kW
# Overvoltage violation at bus 9, phase B with 3.0 kW
# Overvoltage violation at bus 9, phase B with 4.0 kW
# Overvoltage violation at bus 9, phase B with 5.0 kW
# Overvoltage violation at bus 9, phase B with 6.0 kW
# Overvoltage violation at bus 9, phase B with 7.0 kW
# Overvoltage violation at bus 9, phase B with 8.0 kW
# Overvoltage violation at bus 9, phase B with 9.0 kW
# Overvoltage violation at bus 9, phase B with 10.0 kW
# Overvoltage violation at bus 9, phase B with 11.0 kW
# Overvoltage violation at bus 9, phase B with 12.0 kW
# Overvoltage violation at bus 9, phase B with 13.0 kW
# Overvoltage violation at bus 9, phase B with 14.0 kW
# Overvoltage violation at bus 9, phase B with 15.0 kW
# Overvoltage violation at bus 9, phase B with 16.0 kW
# Overvoltage violation at bus 9, phase B with 17.0 kW
# Overvoltage violation at bus 9, phase B with 18.0 kW
# Overvoltage violation at bus 9, phase B with 19.0 kW
# Overvoltage violation at bus 9, phase B with 20.0 kW
# Overvoltage violation at bus 9, phase C with 0.0 kW
# Overvoltage violation at bus 9, phase C with 1.0 kW
# Overvoltage violation at bus 9, phase C with 2.0 kW
# Overvoltage violation at bus 9, phase C with 3.0 kW
# Overvoltage violation at bus 9, phase C with 4.0 kW
# Overvoltage violation at bus 9, phase C with 5.0 kW
# Overvoltage violation at bus 9, phase C with 6.0 kW
# Overvoltage violation at bus 9, phase C with 7.0 kW
# Overvoltage violation at bus 9, phase C with 8.0 kW
# Overvoltage violation at bus 9, phase C with 9.0 kW
# Overvoltage violation at bus 9, phase C with 10.0 kW
# Overvoltage violation at bus 9, phase C with 11.0 kW
# Overvoltage violation at bus 9, phase C with 12.0 kW
# Overvoltage violation at bus 9, phase C with 13.0 kW
# Overvoltage violation at bus 9, phase C with 14.0 kW
# Overvoltage violation at bus 9, phase C with 15.0 kW
# Overvoltage violation at bus 9, phase C with 16.0 kW
# Overvoltage violation at bus 9, phase C with 17.0 kW
# Overvoltage violation at bus 9, phase C with 18.0 kW
# Overvoltage violation at bus 9, phase C with 19.0 kW
# Overvoltage violation at bus 9, phase C with 20.0 kW
# Overvoltage violation at bus 10, phase A with 0.0 kW
# Overvoltage violation at bus 10, phase A with 1.0 kW
# Overvoltage violation at bus 10, phase A with 2.0 kW
# Overvoltage violation at bus 10, phase A with 3.0 kW
# Overvoltage violation at bus 10, phase A with 4.0 kW
# Overvoltage violation at bus 10, phase A with 5.0 kW
# Overvoltage violation at bus 10, phase A with 6.0 kW
# Overvoltage violation at bus 10, phase A with 7.0 kW
# Overvoltage violation at bus 10, phase A with 8.0 kW
# Overvoltage violation at bus 10, phase A with 9.0 kW
# Overvoltage violation at bus 10, phase A with 10.0 kW
# Overvoltage violation at bus 10, phase A with 11.0 kW
# Overvoltage violation at bus 10, phase A with 12.0 kW
# Overvoltage violation at bus 10, phase A with 13.0 kW
# Overvoltage violation at bus 10, phase A with 14.0 kW
# Overvoltage violation at bus 10, phase A with 15.0 kW
# Overvoltage violation at bus 10, phase A with 16.0 kW
# Overvoltage violation at bus 10, phase A with 17.0 kW
# Overvoltage violation at bus 10, phase A with 18.0 kW
# Overvoltage violation at bus 10, phase A with 19.0 kW
# Overvoltage violation at bus 10, phase A with 20.0 kW
# Overvoltage violation at bus 10, phase B with 0.0 kW
# Overvoltage violation at bus 10, phase B with 1.0 kW
# Overvoltage violation at bus 10, phase B with 2.0 kW
# Overvoltage violation at bus 10, phase B with 3.0 kW
# Overvoltage violation at bus 10, phase B with 4.0 kW
# Overvoltage violation at bus 10, phase B with 5.0 kW
# Overvoltage violation at bus 10, phase B with 6.0 kW
# Overvoltage violation at bus 10, phase B with 7.0 kW
# Overvoltage violation at bus 10, phase B with 8.0 kW
# Overvoltage violation at bus 10, phase B with 9.0 kW
# Overvoltage violation at bus 10, phase B with 10.0 kW
# Overvoltage violation at bus 10, phase B with 11.0 kW
# Overvoltage violation at bus 10, phase B with 12.0 kW
# Overvoltage violation at bus 10, phase B with 13.0 kW
# Overvoltage violation at bus 10, phase B with 14.0 kW
# Overvoltage violation at bus 10, phase B with 15.0 kW
# Overvoltage violation at bus 10, phase B with 16.0 kW
# Overvoltage violation at bus 10, phase B with 17.0 kW
# Overvoltage violation at bus 10, phase B with 18.0 kW
# Overvoltage violation at bus 10, phase B with 19.0 kW
# Overvoltage violation at bus 10, phase B with 20.0 kW
# Overvoltage violation at bus 10, phase C with 0.0 kW
# Overvoltage violation at bus 10, phase C with 1.0 kW
# Overvoltage violation at bus 10, phase C with 2.0 kW
# Overvoltage violation at bus 10, phase C with 3.0 kW
# Overvoltage violation at bus 10, phase C with 4.0 kW
# Overvoltage violation at bus 10, phase C with 5.0 kW
# Overvoltage violation at bus 10, phase C with 6.0 kW
# Overvoltage violation at bus 10, phase C with 7.0 kW
# Overvoltage violation at bus 10, phase C with 8.0 kW
# Overvoltage violation at bus 10, phase C with 9.0 kW
# Overvoltage violation at bus 10, phase C with 10.0 kW
# Overvoltage violation at bus 10, phase C with 11.0 kW
# Overvoltage violation at bus 10, phase C with 12.0 kW
# Overvoltage violation at bus 10, phase C with 13.0 kW
# Overvoltage violation at bus 10, phase C with 14.0 kW
# Overvoltage violation at bus 10, phase C with 15.0 kW
# Overvoltage violation at bus 10, phase C with 16.0 kW
# Overvoltage violation at bus 10, phase C with 17.0 kW
# Overvoltage violation at bus 10, phase C with 18.0 kW
# Overvoltage violation at bus 10, phase C with 19.0 kW
# Overvoltage violation at bus 10, phase C with 20.0 kW
# Overvoltage violation at bus 11, phase A with 0.0 kW
# Overvoltage violation at bus 11, phase A with 1.0 kW
# Overvoltage violation at bus 11, phase A with 2.0 kW
# Overvoltage violation at bus 11, phase A with 3.0 kW
# Overvoltage violation at bus 11, phase A with 4.0 kW
# Overvoltage violation at bus 11, phase A with 5.0 kW
# Overvoltage violation at bus 11, phase A with 6.0 kW
# Overvoltage violation at bus 11, phase A with 7.0 kW
# Overvoltage violation at bus 11, phase A with 8.0 kW
# Overvoltage violation at bus 11, phase A with 9.0 kW
# Overvoltage violation at bus 11, phase A with 10.0 kW
# Overvoltage violation at bus 11, phase A with 11.0 kW
# Overvoltage violation at bus 11, phase A with 12.0 kW
# Overvoltage violation at bus 11, phase A with 13.0 kW
# Overvoltage violation at bus 11, phase A with 14.0 kW
# Overvoltage violation at bus 11, phase A with 15.0 kW
# Overvoltage violation at bus 11, phase A with 16.0 kW
# Overvoltage violation at bus 11, phase A with 17.0 kW
# Overvoltage violation at bus 11, phase A with 18.0 kW
# Overvoltage violation at bus 11, phase A with 19.0 kW
# Overvoltage violation at bus 11, phase A with 20.0 kW
# Overvoltage violation at bus 11, phase B with 0.0 kW
# Overvoltage violation at bus 11, phase B with 1.0 kW
# Overvoltage violation at bus 11, phase B with 2.0 kW
# Overvoltage violation at bus 11, phase B with 3.0 kW
# Overvoltage violation at bus 11, phase B with 4.0 kW
# Overvoltage violation at bus 11, phase B with 5.0 kW
# Overvoltage violation at bus 11, phase B with 6.0 kW
# Overvoltage violation at bus 11, phase B with 7.0 kW
# Overvoltage violation at bus 11, phase B with 8.0 kW
# Overvoltage violation at bus 11, phase B with 9.0 kW
# Overvoltage violation at bus 11, phase B with 10.0 kW
# Overvoltage violation at bus 11, phase B with 11.0 kW
# Overvoltage violation at bus 11, phase B with 12.0 kW
# Overvoltage violation at bus 11, phase B with 13.0 kW
# Overvoltage violation at bus 11, phase B with 14.0 kW
# Overvoltage violation at bus 11, phase B with 15.0 kW
# Overvoltage violation at bus 11, phase B with 16.0 kW
# Overvoltage violation at bus 11, phase B with 17.0 kW
# Overvoltage violation at bus 11, phase B with 18.0 kW
# Overvoltage violation at bus 11, phase B with 19.0 kW
# Overvoltage violation at bus 11, phase B with 20.0 kW
# Overvoltage violation at bus 11, phase C with 0.0 kW
# Overvoltage violation at bus 11, phase C with 1.0 kW
# Overvoltage violation at bus 11, phase C with 2.0 kW
# Overvoltage violation at bus 11, phase C with 3.0 kW
# Overvoltage violation at bus 11, phase C with 4.0 kW
# Overvoltage violation at bus 11, phase C with 5.0 kW
# Overvoltage violation at bus 11, phase C with 6.0 kW
# Overvoltage violation at bus 11, phase C with 7.0 kW
# Overvoltage violation at bus 11, phase C with 8.0 kW
# Overvoltage violation at bus 11, phase C with 9.0 kW
# Overvoltage violation at bus 11, phase C with 10.0 kW
# Overvoltage violation at bus 11, phase C with 11.0 kW
# Overvoltage violation at bus 11, phase C with 12.0 kW
# Overvoltage violation at bus 11, phase C with 13.0 kW
# Overvoltage violation at bus 11, phase C with 14.0 kW
# Overvoltage violation at bus 11, phase C with 15.0 kW
# Overvoltage violation at bus 11, phase C with 16.0 kW
# Overvoltage violation at bus 11, phase C with 17.0 kW
# Overvoltage violation at bus 11, phase C with 18.0 kW
# Overvoltage violation at bus 11, phase C with 19.0 kW
# Overvoltage violation at bus 11, phase C with 20.0 kW
# Overvoltage violation at bus 12, phase A with 0.0 kW
# Overvoltage violation at bus 12, phase A with 1.0 kW
# Overvoltage violation at bus 12, phase A with 2.0 kW
# Overvoltage violation at bus 12, phase A with 3.0 kW
# Overvoltage violation at bus 12, phase A with 4.0 kW
# Overvoltage violation at bus 12, phase A with 5.0 kW
# Overvoltage violation at bus 12, phase A with 6.0 kW
# Overvoltage violation at bus 12, phase A with 7.0 kW
# Overvoltage violation at bus 12, phase A with 8.0 kW
# Overvoltage violation at bus 12, phase A with 9.0 kW
# Overvoltage violation at bus 12, phase A with 10.0 kW
# Overvoltage violation at bus 12, phase A with 11.0 kW
# Overvoltage violation at bus 12, phase A with 12.0 kW
# Overvoltage violation at bus 12, phase A with 13.0 kW
# Overvoltage violation at bus 12, phase A with 14.0 kW
# Overvoltage violation at bus 12, phase A with 15.0 kW
# Overvoltage violation at bus 12, phase A with 16.0 kW
# Overvoltage violation at bus 12, phase A with 17.0 kW
# Overvoltage violation at bus 12, phase A with 18.0 kW
# Overvoltage violation at bus 12, phase A with 19.0 kW
# Overvoltage violation at bus 12, phase A with 20.0 kW
# Overvoltage violation at bus 12, phase B with 0.0 kW
# Overvoltage violation at bus 12, phase B with 1.0 kW
# Overvoltage violation at bus 12, phase B with 2.0 kW
# Overvoltage violation at bus 12, phase B with 3.0 kW
# Overvoltage violation at bus 12, phase B with 4.0 kW
# Overvoltage violation at bus 12, phase B with 5.0 kW
# Overvoltage violation at bus 12, phase B with 6.0 kW
# Overvoltage violation at bus 12, phase B with 7.0 kW
# Overvoltage violation at bus 12, phase B with 8.0 kW
# Overvoltage violation at bus 12, phase B with 9.0 kW
# Overvoltage violation at bus 12, phase B with 10.0 kW
# Overvoltage violation at bus 12, phase B with 11.0 kW
# Overvoltage violation at bus 12, phase B with 12.0 kW
# Overvoltage violation at bus 12, phase B with 13.0 kW
# Overvoltage violation at bus 12, phase B with 14.0 kW
# Overvoltage violation at bus 12, phase B with 15.0 kW
# Overvoltage violation at bus 12, phase B with 16.0 kW
# Overvoltage violation at bus 12, phase B with 17.0 kW
# Overvoltage violation at bus 12, phase B with 18.0 kW
# Overvoltage violation at bus 12, phase B with 19.0 kW
# Overvoltage violation at bus 12, phase B with 20.0 kW
# Overvoltage violation at bus 12, phase C with 0.0 kW
# Overvoltage violation at bus 12, phase C with 1.0 kW
# Overvoltage violation at bus 12, phase C with 2.0 kW
# Overvoltage violation at bus 12, phase C with 3.0 kW
# Overvoltage violation at bus 12, phase C with 4.0 kW
# Overvoltage violation at bus 12, phase C with 5.0 kW
# Overvoltage violation at bus 12, phase C with 6.0 kW
# Overvoltage violation at bus 12, phase C with 7.0 kW
# Overvoltage violation at bus 12, phase C with 8.0 kW
# Overvoltage violation at bus 12, phase C with 9.0 kW
# Overvoltage violation at bus 12, phase C with 10.0 kW
# Overvoltage violation at bus 12, phase C with 11.0 kW
# Overvoltage violation at bus 12, phase C with 12.0 kW
# Overvoltage violation at bus 12, phase C with 13.0 kW
# Overvoltage violation at bus 12, phase C with 14.0 kW
# Overvoltage violation at bus 12, phase C with 15.0 kW
# Overvoltage violation at bus 12, phase C with 16.0 kW
# Overvoltage violation at bus 12, phase C with 17.0 kW
# Overvoltage violation at bus 12, phase C with 18.0 kW
# Overvoltage violation at bus 12, phase C with 19.0 kW
# Overvoltage violation at bus 12, phase C with 20.0 kW
# Overvoltage violation at bus 13, phase A with 0.0 kW
# Overvoltage violation at bus 13, phase A with 1.0 kW
# Overvoltage violation at bus 13, phase A with 2.0 kW
# Overvoltage violation at bus 13, phase A with 3.0 kW
# Overvoltage violation at bus 13, phase A with 4.0 kW
# Overvoltage violation at bus 13, phase A with 5.0 kW
# Overvoltage violation at bus 13, phase A with 6.0 kW
# Overvoltage violation at bus 13, phase A with 7.0 kW
# Overvoltage violation at bus 13, phase A with 8.0 kW
# Overvoltage violation at bus 13, phase A with 9.0 kW
# Overvoltage violation at bus 13, phase A with 10.0 kW
# Overvoltage violation at bus 13, phase A with 11.0 kW
# Overvoltage violation at bus 13, phase A with 12.0 kW
# Overvoltage violation at bus 13, phase A with 13.0 kW
# Overvoltage violation at bus 13, phase A with 14.0 kW
# Overvoltage violation at bus 13, phase A with 15.0 kW
# Overvoltage violation at bus 13, phase A with 16.0 kW
# Overvoltage violation at bus 13, phase A with 17.0 kW
# Overvoltage violation at bus 13, phase A with 18.0 kW
# Overvoltage violation at bus 13, phase A with 19.0 kW
# Overvoltage violation at bus 13, phase A with 20.0 kW
# Overvoltage violation at bus 13, phase B with 0.0 kW
# Overvoltage violation at bus 13, phase B with 1.0 kW
# Overvoltage violation at bus 13, phase B with 2.0 kW
# Overvoltage violation at bus 13, phase B with 3.0 kW
# Overvoltage violation at bus 13, phase B with 4.0 kW
# Overvoltage violation at bus 13, phase B with 5.0 kW
# Overvoltage violation at bus 13, phase B with 6.0 kW
# Overvoltage violation at bus 13, phase B with 7.0 kW
# Overvoltage violation at bus 13, phase B with 8.0 kW
# Overvoltage violation at bus 13, phase B with 9.0 kW
# Overvoltage violation at bus 13, phase B with 10.0 kW
# Overvoltage violation at bus 13, phase B with 11.0 kW
# Overvoltage violation at bus 13, phase B with 12.0 kW
# Overvoltage violation at bus 13, phase B with 13.0 kW
# Overvoltage violation at bus 13, phase B with 14.0 kW
# Overvoltage violation at bus 13, phase B with 15.0 kW
# Overvoltage violation at bus 13, phase B with 16.0 kW
# Overvoltage violation at bus 13, phase B with 17.0 kW
# Overvoltage violation at bus 13, phase B with 18.0 kW
# Overvoltage violation at bus 13, phase B with 19.0 kW
# Overvoltage violation at bus 13, phase B with 20.0 kW
# Overvoltage violation at bus 13, phase C with 0.0 kW
# Overvoltage violation at bus 13, phase C with 1.0 kW
# Overvoltage violation at bus 13, phase C with 2.0 kW
# Overvoltage violation at bus 13, phase C with 3.0 kW
# Overvoltage violation at bus 13, phase C with 4.0 kW
# Overvoltage violation at bus 13, phase C with 5.0 kW
# Overvoltage violation at bus 13, phase C with 6.0 kW
# Overvoltage violation at bus 13, phase C with 7.0 kW
# Overvoltage violation at bus 13, phase C with 8.0 kW
# Overvoltage violation at bus 13, phase C with 9.0 kW
# Overvoltage violation at bus 13, phase C with 10.0 kW
# Overvoltage violation at bus 13, phase C with 11.0 kW
# Overvoltage violation at bus 13, phase C with 12.0 kW
# Overvoltage violation at bus 13, phase C with 13.0 kW
# Overvoltage violation at bus 13, phase C with 14.0 kW
# Overvoltage violation at bus 13, phase C with 15.0 kW
# Overvoltage violation at bus 13, phase C with 16.0 kW
# Overvoltage violation at bus 13, phase C with 17.0 kW
# Overvoltage violation at bus 13, phase C with 18.0 kW
# Overvoltage violation at bus 13, phase C with 19.0 kW
# Overvoltage violation at bus 13, phase C with 20.0 kW
# Overvoltage violation at bus 14, phase A with 0.0 kW
# Overvoltage violation at bus 14, phase A with 1.0 kW
# Overvoltage violation at bus 14, phase A with 2.0 kW
# Overvoltage violation at bus 14, phase A with 3.0 kW
# Overvoltage violation at bus 14, phase A with 4.0 kW
# Overvoltage violation at bus 14, phase A with 5.0 kW
# Overvoltage violation at bus 14, phase A with 6.0 kW
# Overvoltage violation at bus 14, phase A with 7.0 kW
# Overvoltage violation at bus 14, phase A with 8.0 kW
# Overvoltage violation at bus 14, phase A with 9.0 kW
# Overvoltage violation at bus 14, phase A with 10.0 kW
# Overvoltage violation at bus 14, phase A with 11.0 kW
# Overvoltage violation at bus 14, phase A with 12.0 kW
# Overvoltage violation at bus 14, phase A with 13.0 kW
# Overvoltage violation at bus 14, phase A with 14.0 kW
# Overvoltage violation at bus 14, phase A with 15.0 kW
# Overvoltage violation at bus 14, phase A with 16.0 kW
# Overvoltage violation at bus 14, phase A with 17.0 kW
# Overvoltage violation at bus 14, phase A with 18.0 kW
# Overvoltage violation at bus 14, phase A with 19.0 kW
# Overvoltage violation at bus 14, phase A with 20.0 kW
# Overvoltage violation at bus 14, phase B with 0.0 kW
# Overvoltage violation at bus 14, phase B with 1.0 kW
# Overvoltage violation at bus 14, phase B with 2.0 kW
# Overvoltage violation at bus 14, phase B with 3.0 kW
# Overvoltage violation at bus 14, phase B with 4.0 kW
# Overvoltage violation at bus 14, phase B with 5.0 kW
# Overvoltage violation at bus 14, phase B with 6.0 kW
# Overvoltage violation at bus 14, phase B with 7.0 kW
# Overvoltage violation at bus 14, phase B with 8.0 kW
# Overvoltage violation at bus 14, phase B with 9.0 kW
# Overvoltage violation at bus 14, phase B with 10.0 kW
# Overvoltage violation at bus 14, phase B with 11.0 kW
# Overvoltage violation at bus 14, phase B with 12.0 kW
# Overvoltage violation at bus 14, phase B with 13.0 kW
# Overvoltage violation at bus 14, phase B with 14.0 kW
# Overvoltage violation at bus 14, phase B with 15.0 kW
# Overvoltage violation at bus 14, phase B with 16.0 kW
# Overvoltage violation at bus 14, phase B with 17.0 kW
# Overvoltage violation at bus 14, phase B with 18.0 kW
# Overvoltage violation at bus 14, phase B with 19.0 kW
# Overvoltage violation at bus 14, phase B with 20.0 kW
# Overvoltage violation at bus 14, phase C with 0.0 kW
# Overvoltage violation at bus 14, phase C with 1.0 kW
# Overvoltage violation at bus 14, phase C with 2.0 kW
# Overvoltage violation at bus 14, phase C with 3.0 kW
# Overvoltage violation at bus 14, phase C with 4.0 kW
# Overvoltage violation at bus 14, phase C with 5.0 kW
# Overvoltage violation at bus 14, phase C with 6.0 kW
# Overvoltage violation at bus 14, phase C with 7.0 kW
# Overvoltage violation at bus 14, phase C with 8.0 kW
# Overvoltage violation at bus 14, phase C with 9.0 kW
# Overvoltage violation at bus 14, phase C with 10.0 kW
# Overvoltage violation at bus 14, phase C with 11.0 kW
# Overvoltage violation at bus 14, phase C with 12.0 kW
# Overvoltage violation at bus 14, phase C with 13.0 kW
# Overvoltage violation at bus 14, phase C with 14.0 kW
# Overvoltage violation at bus 14, phase C with 15.0 kW
# Overvoltage violation at bus 14, phase C with 16.0 kW
# Overvoltage violation at bus 14, phase C with 17.0 kW
# Overvoltage violation at bus 14, phase C with 18.0 kW
# Overvoltage violation at bus 14, phase C with 19.0 kW
# Overvoltage violation at bus 14, phase C with 20.0 kW
# Overvoltage violation at bus 15, phase A with 0.0 kW
# Overvoltage violation at bus 15, phase A with 1.0 kW
# Overvoltage violation at bus 15, phase A with 2.0 kW
# Overvoltage violation at bus 15, phase A with 3.0 kW
# Overvoltage violation at bus 15, phase A with 4.0 kW
# Overvoltage violation at bus 15, phase A with 5.0 kW
# Overvoltage violation at bus 15, phase A with 6.0 kW
# Overvoltage violation at bus 15, phase A with 7.0 kW
# Overvoltage violation at bus 15, phase A with 8.0 kW
# Overvoltage violation at bus 15, phase A with 9.0 kW
# Overvoltage violation at bus 15, phase A with 10.0 kW
# Overvoltage violation at bus 15, phase A with 11.0 kW
# Overvoltage violation at bus 15, phase A with 12.0 kW
# Overvoltage violation at bus 15, phase A with 13.0 kW
# Overvoltage violation at bus 15, phase A with 14.0 kW
# Overvoltage violation at bus 15, phase A with 15.0 kW
# Overvoltage violation at bus 15, phase A with 16.0 kW
# Overvoltage violation at bus 15, phase A with 17.0 kW
# Overvoltage violation at bus 15, phase A with 18.0 kW
# Overvoltage violation at bus 15, phase A with 19.0 kW
# Overvoltage violation at bus 15, phase A with 20.0 kW
# Overvoltage violation at bus 15, phase B with 0.0 kW
# Overvoltage violation at bus 15, phase B with 1.0 kW
# Overvoltage violation at bus 15, phase B with 2.0 kW
# Overvoltage violation at bus 15, phase B with 3.0 kW
# Overvoltage violation at bus 15, phase B with 4.0 kW
# Overvoltage violation at bus 15, phase B with 5.0 kW
# Overvoltage violation at bus 15, phase B with 6.0 kW
# Overvoltage violation at bus 15, phase B with 7.0 kW
# Overvoltage violation at bus 15, phase B with 8.0 kW
# Overvoltage violation at bus 15, phase B with 9.0 kW
# Overvoltage violation at bus 15, phase B with 10.0 kW
# Overvoltage violation at bus 15, phase B with 11.0 kW
# Overvoltage violation at bus 15, phase B with 12.0 kW
# Overvoltage violation at bus 15, phase B with 13.0 kW
# Overvoltage violation at bus 15, phase B with 14.0 kW
# Overvoltage violation at bus 15, phase B with 15.0 kW
# Overvoltage violation at bus 15, phase B with 16.0 kW
# Overvoltage violation at bus 15, phase B with 17.0 kW
# Overvoltage violation at bus 15, phase B with 18.0 kW
# Overvoltage violation at bus 15, phase B with 19.0 kW
# Overvoltage violation at bus 15, phase B with 20.0 kW
# Overvoltage violation at bus 15, phase C with 0.0 kW
# Overvoltage violation at bus 15, phase C with 1.0 kW
# Overvoltage violation at bus 15, phase C with 2.0 kW
# Overvoltage violation at bus 15, phase C with 3.0 kW
# Overvoltage violation at bus 15, phase C with 4.0 kW
# Overvoltage violation at bus 15, phase C with 5.0 kW
# Overvoltage violation at bus 15, phase C with 6.0 kW
# Overvoltage violation at bus 15, phase C with 7.0 kW
# Overvoltage violation at bus 15, phase C with 8.0 kW
# Overvoltage violation at bus 15, phase C with 9.0 kW
# Overvoltage violation at bus 15, phase C with 10.0 kW
# Overvoltage violation at bus 15, phase C with 11.0 kW
# Overvoltage violation at bus 15, phase C with 12.0 kW
# Overvoltage violation at bus 15, phase C with 13.0 kW
# Overvoltage violation at bus 15, phase C with 14.0 kW
# Overvoltage violation at bus 15, phase C with 15.0 kW
# Overvoltage violation at bus 15, phase C with 16.0 kW
# Overvoltage violation at bus 15, phase C with 17.0 kW
# Overvoltage violation at bus 15, phase C with 18.0 kW
# Overvoltage violation at bus 15, phase C with 19.0 kW
# Overvoltage violation at bus 15, phase C with 20.0 kW
# Overvoltage violation at bus 16, phase A with 0.0 kW
# Overvoltage violation at bus 16, phase A with 1.0 kW
# Overvoltage violation at bus 16, phase A with 2.0 kW
# Overvoltage violation at bus 16, phase A with 3.0 kW
# Overvoltage violation at bus 16, phase A with 4.0 kW
# Overvoltage violation at bus 16, phase A with 5.0 kW
# Overvoltage violation at bus 16, phase A with 6.0 kW
# Overvoltage violation at bus 16, phase A with 7.0 kW
# Overvoltage violation at bus 16, phase A with 8.0 kW
# Overvoltage violation at bus 16, phase A with 9.0 kW
# Overvoltage violation at bus 16, phase A with 10.0 kW
# Overvoltage violation at bus 16, phase A with 11.0 kW
# Overvoltage violation at bus 16, phase A with 12.0 kW
# Overvoltage violation at bus 16, phase A with 13.0 kW
# Overvoltage violation at bus 16, phase A with 14.0 kW
# Overvoltage violation at bus 16, phase A with 15.0 kW
# Overvoltage violation at bus 16, phase A with 16.0 kW
# Overvoltage violation at bus 16, phase A with 17.0 kW
# Overvoltage violation at bus 16, phase A with 18.0 kW
# Overvoltage violation at bus 16, phase A with 19.0 kW
# Overvoltage violation at bus 16, phase A with 20.0 kW
# Overvoltage violation at bus 16, phase B with 0.0 kW
# Overvoltage violation at bus 16, phase B with 1.0 kW
# Overvoltage violation at bus 16, phase B with 2.0 kW
# ...
# Overvoltage violation at bus 203, phase B with 12.0 kW
# Overvoltage violation at bus 203, phase B with 13.0 kW
# Overvoltage violation at bus 203, phase B with 14.0 kW
# Overvoltage violation at bus 203, phase B with 15.0 kW
# Overvoltage violation at bus 203, phase B with 16.0 kW
# Overvoltage violation at bus 203, phase B with 17.0 kW
# Overvoltage violation at bus 203, phase B with 18.0 kW
# Overvoltage violation at bus 203, phase B with 19.0 kW
# Overvoltage violation at bus 203, phase B with 20.0 kW
# Overvoltage violation at bus 203, phase C with 0.0 kW
# Overvoltage violation at bus 203, phase C with 1.0 kW
# Overvoltage violation at bus 203, phase C with 2.0 kW
# Overvoltage violation at bus 203, phase C with 3.0 kW
# Overvoltage violation at bus 203, phase C with 4.0 kW
# Overvoltage violation at bus 203, phase C with 5.0 kW
# Overvoltage violation at bus 203, phase C with 6.0 kW
# Overvoltage violation at bus 203, phase C with 7.0 kW
# Overvoltage violation at bus 203, phase C with 8.0 kW
# Overvoltage violation at bus 203, phase C with 9.0 kW
# Overvoltage violation at bus 203, phase C with 10.0 kW
# Overvoltage violation at bus 203, phase C with 11.0 kW
# Overvoltage violation at bus 203, phase C with 12.0 kW
# Overvoltage violation at bus 203, phase C with 13.0 kW
# Overvoltage violation at bus 203, phase C with 14.0 kW
# Overvoltage violation at bus 203, phase C with 15.0 kW
# Overvoltage violation at bus 203, phase C with 16.0 kW
# Overvoltage violation at bus 203, phase C with 17.0 kW
# Overvoltage violation at bus 203, phase C with 18.0 kW
# Overvoltage violation at bus 203, phase C with 19.0 kW
# Overvoltage violation at bus 203, phase C with 20.0 kW
# Overvoltage violation at bus 204, phase A with 0.0 kW
# Overvoltage violation at bus 204, phase A with 1.0 kW
# Overvoltage violation at bus 204, phase A with 2.0 kW
# Overvoltage violation at bus 204, phase A with 3.0 kW
# Overvoltage violation at bus 204, phase A with 4.0 kW
# Overvoltage violation at bus 204, phase A with 5.0 kW
# Overvoltage violation at bus 204, phase A with 6.0 kW
# Overvoltage violation at bus 204, phase A with 7.0 kW
# Overvoltage violation at bus 204, phase A with 8.0 kW
# Overvoltage violation at bus 204, phase A with 9.0 kW
# Overvoltage violation at bus 204, phase A with 10.0 kW
# Overvoltage violation at bus 204, phase A with 11.0 kW
# Overvoltage violation at bus 204, phase A with 12.0 kW
# Overvoltage violation at bus 204, phase A with 13.0 kW
# Overvoltage violation at bus 204, phase A with 14.0 kW
# Overvoltage violation at bus 204, phase A with 15.0 kW
# Overvoltage violation at bus 204, phase A with 16.0 kW
# Overvoltage violation at bus 204, phase A with 17.0 kW
# Overvoltage violation at bus 204, phase A with 18.0 kW
# Overvoltage violation at bus 204, phase A with 19.0 kW
# Overvoltage violation at bus 204, phase A with 20.0 kW
# Overvoltage violation at bus 204, phase B with 0.0 kW
# Overvoltage violation at bus 204, phase B with 1.0 kW
# Overvoltage violation at bus 204, phase B with 2.0 kW
# Overvoltage violation at bus 204, phase B with 3.0 kW
# Overvoltage violation at bus 204, phase B with 4.0 kW
# Overvoltage violation at bus 204, phase B with 5.0 kW
# Overvoltage violation at bus 204, phase B with 6.0 kW
# Overvoltage violation at bus 204, phase B with 7.0 kW
# Overvoltage violation at bus 204, phase B with 8.0 kW
# Overvoltage violation at bus 204, phase B with 9.0 kW
# Overvoltage violation at bus 204, phase B with 10.0 kW
# Overvoltage violation at bus 204, phase B with 11.0 kW
# Overvoltage violation at bus 204, phase B with 12.0 kW
# Overvoltage violation at bus 204, phase B with 13.0 kW
# Overvoltage violation at bus 204, phase B with 14.0 kW
# Overvoltage violation at bus 204, phase B with 15.0 kW
# Overvoltage violation at bus 204, phase B with 16.0 kW
# Overvoltage violation at bus 204, phase B with 17.0 kW
# Overvoltage violation at bus 204, phase B with 18.0 kW
# Overvoltage violation at bus 204, phase B with 19.0 kW
# Overvoltage violation at bus 204, phase B with 20.0 kW
# Overvoltage violation at bus 204, phase C with 0.0 kW
# Overvoltage violation at bus 204, phase C with 1.0 kW
# Overvoltage violation at bus 204, phase C with 2.0 kW
# Overvoltage violation at bus 204, phase C with 3.0 kW
# Overvoltage violation at bus 204, phase C with 4.0 kW
# Overvoltage violation at bus 204, phase C with 5.0 kW
# Overvoltage violation at bus 204, phase C with 6.0 kW
# Overvoltage violation at bus 204, phase C with 7.0 kW
# Overvoltage violation at bus 204, phase C with 8.0 kW
# Overvoltage violation at bus 204, phase C with 9.0 kW
# Overvoltage violation at bus 204, phase C with 10.0 kW
# Overvoltage violation at bus 204, phase C with 11.0 kW
# Overvoltage violation at bus 204, phase C with 12.0 kW
# Overvoltage violation at bus 204, phase C with 13.0 kW
# Overvoltage violation at bus 204, phase C with 14.0 kW
# Overvoltage violation at bus 204, phase C with 15.0 kW
# Overvoltage violation at bus 204, phase C with 16.0 kW
# Overvoltage violation at bus 204, phase C with 17.0 kW
# Overvoltage violation at bus 204, phase C with 18.0 kW
# Overvoltage violation at bus 204, phase C with 19.0 kW
# Overvoltage violation at bus 204, phase C with 20.0 kW
# Overvoltage violation at bus 205, phase A with 0.0 kW
# Overvoltage violation at bus 205, phase A with 1.0 kW
# Overvoltage violation at bus 205, phase A with 2.0 kW
# Overvoltage violation at bus 205, phase A with 3.0 kW
# Overvoltage violation at bus 205, phase A with 4.0 kW
# Overvoltage violation at bus 205, phase A with 5.0 kW
# Overvoltage violation at bus 205, phase A with 6.0 kW
# Overvoltage violation at bus 205, phase A with 7.0 kW
# Overvoltage violation at bus 205, phase A with 8.0 kW
# Overvoltage violation at bus 205, phase A with 9.0 kW
# Overvoltage violation at bus 205, phase A with 10.0 kW
# Overvoltage violation at bus 205, phase A with 11.0 kW
# Overvoltage violation at bus 205, phase A with 12.0 kW
# Overvoltage violation at bus 205, phase A with 13.0 kW
# Overvoltage violation at bus 205, phase A with 14.0 kW
# Overvoltage violation at bus 205, phase A with 15.0 kW
# Overvoltage violation at bus 205, phase A with 16.0 kW
# Overvoltage violation at bus 205, phase A with 17.0 kW
# Overvoltage violation at bus 205, phase A with 18.0 kW
# Overvoltage violation at bus 205, phase A with 19.0 kW
# Overvoltage violation at bus 205, phase A with 20.0 kW
# Overvoltage violation at bus 205, phase B with 0.0 kW
# Overvoltage violation at bus 205, phase B with 1.0 kW
# Overvoltage violation at bus 205, phase B with 2.0 kW
# Overvoltage violation at bus 205, phase B with 3.0 kW
# Overvoltage violation at bus 205, phase B with 4.0 kW
# Overvoltage violation at bus 205, phase B with 5.0 kW
# Overvoltage violation at bus 205, phase B with 6.0 kW
# Overvoltage violation at bus 205, phase B with 7.0 kW
# Overvoltage violation at bus 205, phase B with 8.0 kW
# Overvoltage violation at bus 205, phase B with 9.0 kW
# Overvoltage violation at bus 205, phase B with 10.0 kW
# Overvoltage violation at bus 205, phase B with 11.0 kW
# Overvoltage violation at bus 205, phase B with 12.0 kW
# Overvoltage violation at bus 205, phase B with 13.0 kW
# Overvoltage violation at bus 205, phase B with 14.0 kW
# Overvoltage violation at bus 205, phase B with 15.0 kW
# Overvoltage violation at bus 205, phase B with 16.0 kW
# Overvoltage violation at bus 205, phase B with 17.0 kW
# Overvoltage violation at bus 205, phase B with 18.0 kW
# Overvoltage violation at bus 205, phase B with 19.0 kW
# Overvoltage violation at bus 205, phase B with 20.0 kW
# Overvoltage violation at bus 205, phase C with 0.0 kW
# Overvoltage violation at bus 205, phase C with 1.0 kW
# Overvoltage violation at bus 205, phase C with 2.0 kW
# Overvoltage violation at bus 205, phase C with 3.0 kW
# Overvoltage violation at bus 205, phase C with 4.0 kW
# Overvoltage violation at bus 205, phase C with 5.0 kW
# Overvoltage violation at bus 205, phase C with 6.0 kW
# Overvoltage violation at bus 205, phase C with 7.0 kW
# Overvoltage violation at bus 205, phase C with 8.0 kW
# Overvoltage violation at bus 205, phase C with 9.0 kW
# Overvoltage violation at bus 205, phase C with 10.0 kW
# Overvoltage violation at bus 205, phase C with 11.0 kW
# Overvoltage violation at bus 205, phase C with 12.0 kW
# Overvoltage violation at bus 205, phase C with 13.0 kW
# Overvoltage violation at bus 205, phase C with 14.0 kW
# Overvoltage violation at bus 205, phase C with 15.0 kW
# Overvoltage violation at bus 205, phase C with 16.0 kW
# Overvoltage violation at bus 205, phase C with 17.0 kW
# Overvoltage violation at bus 205, phase C with 18.0 kW
# Overvoltage violation at bus 205, phase C with 19.0 kW
# Overvoltage violation at bus 205, phase C with 20.0 kW
# Overvoltage violation at bus 206, phase A with 0.0 kW
# Overvoltage violation at bus 206, phase A with 1.0 kW
# Overvoltage violation at bus 206, phase A with 2.0 kW
# Overvoltage violation at bus 206, phase A with 3.0 kW
# Overvoltage violation at bus 206, phase A with 4.0 kW
# Overvoltage violation at bus 206, phase A with 5.0 kW
# Overvoltage violation at bus 206, phase A with 6.0 kW
# Overvoltage violation at bus 206, phase A with 7.0 kW
# Overvoltage violation at bus 206, phase A with 8.0 kW
# Overvoltage violation at bus 206, phase A with 9.0 kW
# Overvoltage violation at bus 206, phase A with 10.0 kW
# Overvoltage violation at bus 206, phase A with 11.0 kW
# Overvoltage violation at bus 206, phase A with 12.0 kW
# Overvoltage violation at bus 206, phase A with 13.0 kW
# Overvoltage violation at bus 206, phase A with 14.0 kW
# Overvoltage violation at bus 206, phase A with 15.0 kW
# Overvoltage violation at bus 206, phase A with 16.0 kW
# Overvoltage violation at bus 206, phase A with 17.0 kW
# Overvoltage violation at bus 206, phase A with 18.0 kW
# Overvoltage violation at bus 206, phase A with 19.0 kW
# Overvoltage violation at bus 206, phase A with 20.0 kW
# Overvoltage violation at bus 206, phase B with 0.0 kW
# Overvoltage violation at bus 206, phase B with 1.0 kW
# Overvoltage violation at bus 206, phase B with 2.0 kW
# Overvoltage violation at bus 206, phase B with 3.0 kW
# Overvoltage violation at bus 206, phase B with 4.0 kW
# Overvoltage violation at bus 206, phase B with 5.0 kW
# Overvoltage violation at bus 206, phase B with 6.0 kW
# Overvoltage violation at bus 206, phase B with 7.0 kW
# Overvoltage violation at bus 206, phase B with 8.0 kW
# Overvoltage violation at bus 206, phase B with 9.0 kW
# Overvoltage violation at bus 206, phase B with 10.0 kW
# Overvoltage violation at bus 206, phase B with 11.0 kW
# Overvoltage violation at bus 206, phase B with 12.0 kW
# Overvoltage violation at bus 206, phase B with 13.0 kW
# Overvoltage violation at bus 206, phase B with 14.0 kW
# Overvoltage violation at bus 206, phase B with 15.0 kW
# Overvoltage violation at bus 206, phase B with 16.0 kW
# Overvoltage violation at bus 206, phase B with 17.0 kW
# Overvoltage violation at bus 206, phase B with 18.0 kW
# Overvoltage violation at bus 206, phase B with 19.0 kW
# Overvoltage violation at bus 206, phase B with 20.0 kW
# Overvoltage violation at bus 206, phase C with 0.0 kW
# Overvoltage violation at bus 206, phase C with 1.0 kW
# Overvoltage violation at bus 206, phase C with 2.0 kW
# Overvoltage violation at bus 206, phase C with 3.0 kW
# Overvoltage violation at bus 206, phase C with 4.0 kW
# Overvoltage violation at bus 206, phase C with 5.0 kW
# Overvoltage violation at bus 206, phase C with 6.0 kW
# Overvoltage violation at bus 206, phase C with 7.0 kW
# Overvoltage violation at bus 206, phase C with 8.0 kW
# Overvoltage violation at bus 206, phase C with 9.0 kW
# Overvoltage violation at bus 206, phase C with 10.0 kW
# Overvoltage violation at bus 206, phase C with 11.0 kW
# Overvoltage violation at bus 206, phase C with 12.0 kW
# Overvoltage violation at bus 206, phase C with 13.0 kW
# Overvoltage violation at bus 206, phase C with 14.0 kW
# Overvoltage violation at bus 206, phase C with 15.0 kW
# Overvoltage violation at bus 206, phase C with 16.0 kW
# Overvoltage violation at bus 206, phase C with 17.0 kW
# Overvoltage violation at bus 206, phase C with 18.0 kW
# Overvoltage violation at bus 206, phase C with 19.0 kW
# Overvoltage violation at bus 206, phase C with 20.0 kW
# Overvoltage violation at bus 207, phase A with 0.0 kW
# Overvoltage violation at bus 207, phase A with 1.0 kW
# Overvoltage violation at bus 207, phase A with 2.0 kW
# Overvoltage violation at bus 207, phase A with 3.0 kW
# Overvoltage violation at bus 207, phase A with 4.0 kW
# Overvoltage violation at bus 207, phase A with 5.0 kW
# Overvoltage violation at bus 207, phase A with 6.0 kW
# Overvoltage violation at bus 207, phase A with 7.0 kW
# Overvoltage violation at bus 207, phase A with 8.0 kW
# Overvoltage violation at bus 207, phase A with 9.0 kW
# Overvoltage violation at bus 207, phase A with 10.0 kW
# Overvoltage violation at bus 207, phase A with 11.0 kW
# Overvoltage violation at bus 207, phase A with 12.0 kW
# Overvoltage violation at bus 207, phase A with 13.0 kW
# Overvoltage violation at bus 207, phase A with 14.0 kW
# Overvoltage violation at bus 207, phase A with 15.0 kW
# Overvoltage violation at bus 207, phase A with 16.0 kW
# Overvoltage violation at bus 207, phase A with 17.0 kW
# Overvoltage violation at bus 207, phase A with 18.0 kW
# Overvoltage violation at bus 207, phase A with 19.0 kW
# Overvoltage violation at bus 207, phase A with 20.0 kW
# Overvoltage violation at bus 207, phase B with 0.0 kW
# Overvoltage violation at bus 207, phase B with 1.0 kW
# Overvoltage violation at bus 207, phase B with 2.0 kW
# Overvoltage violation at bus 207, phase B with 3.0 kW
# Overvoltage violation at bus 207, phase B with 4.0 kW
# Overvoltage violation at bus 207, phase B with 5.0 kW
# Overvoltage violation at bus 207, phase B with 6.0 kW
# Overvoltage violation at bus 207, phase B with 7.0 kW
# Overvoltage violation at bus 207, phase B with 8.0 kW
# Overvoltage violation at bus 207, phase B with 9.0 kW
# Overvoltage violation at bus 207, phase B with 10.0 kW
# Overvoltage violation at bus 207, phase B with 11.0 kW
# Overvoltage violation at bus 207, phase B with 12.0 kW
# Overvoltage violation at bus 207, phase B with 13.0 kW
# Overvoltage violation at bus 207, phase B with 14.0 kW
# Overvoltage violation at bus 207, phase B with 15.0 kW
# Overvoltage violation at bus 207, phase B with 16.0 kW
# Overvoltage violation at bus 207, phase B with 17.0 kW
# Overvoltage violation at bus 207, phase B with 18.0 kW
# Overvoltage violation at bus 207, phase B with 19.0 kW
# Overvoltage violation at bus 207, phase B with 20.0 kW
# Overvoltage violation at bus 207, phase C with 0.0 kW
# Overvoltage violation at bus 207, phase C with 1.0 kW
# Overvoltage violation at bus 207, phase C with 2.0 kW
# Overvoltage violation at bus 207, phase C with 3.0 kW
# Overvoltage violation at bus 207, phase C with 4.0 kW
# Overvoltage violation at bus 207, phase C with 5.0 kW
# Overvoltage violation at bus 207, phase C with 6.0 kW
# Overvoltage violation at bus 207, phase C with 7.0 kW
# Overvoltage violation at bus 207, phase C with 8.0 kW
# Overvoltage violation at bus 207, phase C with 9.0 kW
# Overvoltage violation at bus 207, phase C with 10.0 kW
# Overvoltage violation at bus 207, phase C with 11.0 kW
# Overvoltage violation at bus 207, phase C with 12.0 kW
# Overvoltage violation at bus 207, phase C with 13.0 kW
# Overvoltage violation at bus 207, phase C with 14.0 kW
# Overvoltage violation at bus 207, phase C with 15.0 kW
# Overvoltage violation at bus 207, phase C with 16.0 kW
# Overvoltage violation at bus 207, phase C with 17.0 kW
# Overvoltage violation at bus 207, phase C with 18.0 kW
# Overvoltage violation at bus 207, phase C with 19.0 kW
# Overvoltage violation at bus 207, phase C with 20.0 kW
# Overvoltage violation at bus 208, phase A with 0.0 kW
# Overvoltage violation at bus 208, phase A with 1.0 kW
# Overvoltage violation at bus 208, phase A with 2.0 kW
# Overvoltage violation at bus 208, phase A with 3.0 kW
# Overvoltage violation at bus 208, phase A with 4.0 kW
# Overvoltage violation at bus 208, phase A with 5.0 kW
# Overvoltage violation at bus 208, phase A with 6.0 kW
# Overvoltage violation at bus 208, phase A with 7.0 kW
# Overvoltage violation at bus 208, phase A with 8.0 kW
# Overvoltage violation at bus 208, phase A with 9.0 kW
# Overvoltage violation at bus 208, phase A with 10.0 kW

# %%
ev_hc_results = hc_deterministic(net_on_peak_566, add_kw=1.0, max_kw=20.0, pv=False, ev=True)

ev_hc_results.to_csv(os.path.join(output_dir, 'ev_hc_results_on_peak_566.csv'))

# %%
pvev_hc_results = hc_deterministic(net_on_peak_566, add_kw=1.0, max_kw=20.0, pv=True, ev=True)

pvev_hc_results.to_csv(os.path.join(output_dir, 'pvev_hc_results_on_peak_566.csv'))
